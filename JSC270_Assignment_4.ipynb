# %% [markdown]
# # **Part1**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_data_url = 'https://raw.githubusercontent.com/OulinG138/JSC270-Winter-A4/main/covid-tweets-train.csv?token=GHSAT0AAAAAACQEPTXH4ACHJVAPFBNXES3GZQIL7VQ'
train_data = pd.read_csv(train_data_url)
train_data = train_data.drop('Unnamed: 0', axis=1)

# %%
test_data_url = 'https://raw.githubusercontent.com/OulinG138/JSC270-Winter-A4/main/covid-tweets-test.csv?token=GHSAT0AAAAAACQEPTXGS75RXHC6WTB6IUAKZQIL3HA'
test_data = pd.read_csv(test_data_url)
test_data = test_data.drop('Unnamed: 0', axis=1)

# %%
test_data
# Out:
#                                           OriginalTweet  Sentiment
# 0     TRENDING: New Yorkers encounter empty supermar...          0
# 1     When I couldn't find hand sanitizer at Fred Me...          2
# 2     Find out how you can protect yourself and love...          2
# 3     #Panic buying hits #NewYork City as anxious sh...          0
# 4     #toiletpaper #dunnypaper #coronavirus #coronav...          1
# ...                                                 ...        ...
# 3793  Meanwhile In A Supermarket in Israel -- People...          2
# 3794  Did you panic buy a lot of non-perishable item...          0
# 3795  Asst Prof of Economics @cconces was on @NBCPhi...          1
# 3796  Gov need to do somethings instead of biar je r...          0
# 3797  I and @ForestandPaper members are committed to...          2
#
# [3798 rows x 2 columns]

# %%
train_data
# Out:
#                                            OriginalTweet Sentiment
# 0      @MeNyrbie @Phil_Gahan @Chrisitv https://t.co/i...         1
# 1      advice Talk to your neighbours family to excha...         2
# 2      Coronavirus Australia: Woolworths to give elde...         2
# 3      My food stock is not the only one which is emp...         2
# 4      Me, ready to go at supermarket during the #COV...         0
# ...                                                  ...       ...
# 41150  Airline pilots offering to stock supermarket s...         1
# 41151  Response to complaint not provided citing COVI...         0
# 41152  You know itÂs getting tough when @KameronWild...         2
# 41153  Is it wrong that the smell of hand sanitizer i...         1
# 41154  @TartiiCat Well new/used Rift S are going for ...         0
#
# [41155 rows x 2 columns]

# %% [markdown]
# ### **A**

# %%
valid_train_sentiments = train_data[train_data['Sentiment'].isin(['0', '1', '2'])]['Sentiment'].value_counts(normalize=True)

valid_train_sentiments
# Out:
# 2    0.438434
# 0    0.374159
# 1    0.187407
# Name: Sentiment, dtype: float64
